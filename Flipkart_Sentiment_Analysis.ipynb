# %%
# File Warnings

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
# Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the data

# %%
Badminton = pd.read_csv("data.csv")
Badminton
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 3        Suresh Narayanasamy                       Fair
# 4                  ASHIK P A                Over priced
# ...                      ...                        ...
# 8513                     NaN                        NaN
# 8514                     NaN                        NaN
# 8515                     NaN                        NaN
# 8516                     NaN                        NaN
# 8517                     NaN                        NaN
#
#                   Place of Review  Up Votes  Down Votes     Month  \
# 0      Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1      Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2     Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3        Certified Buyer, Chennai      25.0         1.0       NaN
# 4                             NaN     147.0        24.0  Apr 2016
# ...                           ...       ...         ...       ...
# 8513                          NaN       NaN         NaN       NaN
# 8514                          NaN       NaN         NaN       NaN
# 8515                          NaN       NaN         NaN       NaN
# 8516                          NaN       NaN         NaN       NaN
# 8517                          NaN       NaN         NaN       NaN
#
#                                             Review text  Ratings
# 0     Nice product, good quality, but price is now r...        4
# 1     They didn't supplied Yonex Mavis 350. Outside ...        1
# 2     Worst product. Damaged shuttlecocks packed in ...        1
# 3     Quite O. K. , but nowadays  the quality of the...        3
# 4     Over pricedJust â?¹620 ..from retailer.I didn'...        1
# ...                                                 ...      ...
# 8513                                                NaN        5
# 8514                                                NaN        2
# 8515                                                NaN        4
# 8516                                                NaN        1
# 8517                                                NaN        4
#
# [8518 rows x 8 columns]

# %%
# Basic info

# %%
# Badminton.head()

# %%
# Badminton.tail()

# %%
Badminton.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8518 entries, 0 to 8517
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8508 non-null   object
#  1   Review Title     8508 non-null   object
#  2   Place of Review  8468 non-null   object
#  3   Up Votes         8508 non-null   float64
#  4   Down Votes       8508 non-null   float64
#  5   Month            8053 non-null   object
#  6   Review text      8510 non-null   object
#  7   Ratings          8518 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.5+ KB

# %%
Badminton.describe()
# Out:
#           Up Votes   Down Votes      Ratings
# count  8508.000000  8508.000000  8518.000000
# mean      0.391396     0.121768     4.181028
# std      11.613909     3.248022     1.262200
# min       0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     4.000000
# 50%       0.000000     0.000000     5.000000
# 75%       0.000000     0.000000     5.000000
# max     889.000000   219.000000     5.000000

# %%
# Checking for Null Values

# %%
Badminton.isnull().sum()
# Out:
# Reviewer Name       10
# Review Title        10
# Place of Review     50
# Up Votes            10
# Down Votes          10
# Month              465
# Review text          8
# Ratings              0
# dtype: int64

# %%
# Replacing with Mode

# %%
# Dropping Null Values

# %%
Badminton.dropna(inplace = True)

# %%
# Checking for Duplicates

# %%
Badminton.duplicated().sum()
# Out:
# 0

# %%
# Dropping Duplicates

# %%
Badminton = Badminton.drop_duplicates()

# %%
# Reset Index

# %%
# Reset the index
Badminton.reset_index(drop=True, inplace=True)

# %%
Badminton
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 3                Baji Sankar      Mind-blowing purchase
# 4          Flipkart Customer                  Must buy!
# ...                      ...                        ...
# 8008     vishal kumar ashish                       Nice
# 8009         Nitya Nand  Rai                Good choice
# 8010             Tarun Reddy                    Awesome
# 8011             Jayachandra                  High cost
# 8012            vishnu varma                Really Nice
#
#                   Place of Review  Up Votes  Down Votes     Month  \
# 0      Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1      Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2     Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3      Certified Buyer, Hyderabad     173.0        45.0  Oct 2018
# 4     Certified Buyer, Doom Dooma     403.0       121.0  Jan 2020
# ...                           ...       ...         ...       ...
# 8008    Certified Buyer, Haridwar       0.0         0.0  Oct 2016
# 8009   Certified Buyer, Raebareli       0.0         0.0  Oct 2016
# 8010              Certified Buyer       0.0         0.0  Oct 2016
# 8011   Certified Buyer, Mangalore       0.0         0.0  Dec 2015
# 8012    Certified Buyer, Agartala       0.0         1.0  Sep 2016
#
#                                             Review text  Ratings
# 0     Nice product, good quality, but price is now r...        4
# 1     They didn't supplied Yonex Mavis 350. Outside ...        1
# 2     Worst product. Damaged shuttlecocks packed in ...        1
# 3     Good quality product. Delivered on time.READ MORE        5
# 4     BEST PURCHASE It is a good quality and is more...        5
# ...                                                 ...      ...
# 8008  Thanks to the delivery boy ... Service is alwa...        5
# 8009  Over priced even after 50% discount price is m...        1
# 8010  Too much priced. It was getting me for Rs. 640...        1
# 8011  Hii flipkart customers care..why your delivery...        5
# 8012                       Nice delivery speedREAD MORE        5
#
# [8013 rows x 8 columns]

# %%
# Final cleaned data looks like this ⬆️

# %%
# Visualizing 'Ratings'

# %%
# 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for seaborn
sns.set(style="whitegrid")

# Create subplots with a grid layout
fig, axs = plt.subplots(2, 3, figsize=(12, 8))

# Plot 1: Histogram
sns.histplot(data=Badminton, x='Ratings', bins=10, ax=axs[0, 0])
axs[0, 0].set_title('Histogram of Ratings')
axs[0, 0].set_xlabel('Rating')
axs[0, 0].set_ylabel('Frequency')

# Plot 2: Bar Chart
sns.countplot(data=Badminton, x='Ratings', ax=axs[0, 1])
axs[0, 1].set_title('Bar Chart of Ratings')
axs[0, 1].set_xlabel('Rating')
axs[0, 1].set_ylabel('Count')

# Plot 3: Pie Chart
ratings_counts = Badminton['Ratings'].value_counts()
axs[0, 2].pie(ratings_counts, labels=ratings_counts.index, autopct='%1.1f%%', startangle=140)
axs[0, 2].set_title('Pie Chart of Ratings')

# Plot 4: Box Plot
sns.boxplot(data=Badminton, x='Ratings', ax=axs[1, 0])
axs[1, 0].set_title('Box Plot of Ratings')
axs[1, 0].set_xlabel('Rating')

# Plot 5: Violin Plot
sns.violinplot(data=Badminton, x='Ratings', ax=axs[1, 1])
axs[1, 1].set_title('Violin Plot of Ratings')
axs[1, 1].set_xlabel('Rating')

# Hide the empty subplot
fig.delaxes(axs[1, 2])

# Add spacing between subplots
plt.tight_layout()

# Add overall title
plt.suptitle('Visualizations of Ratings', y=1.05)

# Show the plots
plt.show()

# %%
# Function to classify reviews as positive or negative based on ratings

# %%
def classify_review(rating):
    if rating >= 3.0:
        return 'Positive'
    else:
        return 'Negative'

# %%
Badminton['Sentiment'] = Badminton['Ratings'].apply(classify_review)

# %%
Badminton
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 3                Baji Sankar      Mind-blowing purchase
# 4          Flipkart Customer                  Must buy!
# ...                      ...                        ...
# 8008     vishal kumar ashish                       Nice
# 8009         Nitya Nand  Rai                Good choice
# 8010             Tarun Reddy                    Awesome
# 8011             Jayachandra                  High cost
# 8012            vishnu varma                Really Nice
#
#                   Place of Review  Up Votes  Down Votes     Month  \
# 0      Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1      Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2     Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3      Certified Buyer, Hyderabad     173.0        45.0  Oct 2018
# 4     Certified Buyer, Doom Dooma     403.0       121.0  Jan 2020
# ...                           ...       ...         ...       ...
# 8008    Certified Buyer, Haridwar       0.0         0.0  Oct 2016
# 8009   Certified Buyer, Raebareli       0.0         0.0  Oct 2016
# 8010              Certified Buyer       0.0         0.0  Oct 2016
# 8011   Certified Buyer, Mangalore       0.0         0.0  Dec 2015
# 8012    Certified Buyer, Agartala       0.0         1.0  Sep 2016
#
#                                             Review text  Ratings Sentiment
# 0     Nice product, good quality, but price is now r...        4  Positive
# 1     They didn't supplied Yonex Mavis 350. Outside ...        1  Negative
# 2     Worst product. Damaged shuttlecocks packed in ...        1  Negative
# 3     Good quality product. Delivered on time.READ MORE        5  Positive
# 4     BEST PURCHASE It is a good quality and is more...        5  Positive
# ...                                                 ...      ...       ...
# 8008  Thanks to the delivery boy ... Service is alwa...        5  Positive
# 8009  Over priced even after 50% discount price is m...        1  Negative
# 8010  Too much priced. It was getting me for Rs. 640...        1  Negative
# 8011  Hii flipkart customers care..why your delivery...        5  Positive
# 8012                       Nice delivery speedREAD MORE        5  Positive
#
# [8013 rows x 9 columns]

# %%
# Checking for unique values in 'Sentiment' column

# %%
Badminton['Sentiment'].value_counts()
# Out:
# Positive    7037
# Negative     976
# Name: Sentiment, dtype: int64

# %%
# Wordcloud for most occured words

# %%
from wordcloud import WordCloud

# Concatenate all cleaned text data into a single string
all_text = ' '.join(Badminton['Review text'])

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Input and Output variables

# %%
# Independent Variable

# %%
x = Badminton['Review text']

# %%
# Target Variable

# %%
y = Badminton['Sentiment']

# %%
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
# training data of size 80%
# test data of size 20%

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.8,random_state=1)

# %%
# Pre processing on Train and Test Data

# %%
# Libraries

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
# Declaring 'Stemming' and 'Lemmatization' variables

# %%
Stemming = PorterStemmer()

# %%
Lemmatization = WordNetLemmatizer()

# %%
# # Steps involved in data preprocesing :

# 1. Removing special characters,unwanted numericals 
# 2. Normalize the case(lower)
# 3. Word Tokenization
# 4. Removing stop words
# 5. Stemming or Lemmatization

# %%
#

# %%
# Download NLTK stopwords
nltk.download('stopwords')

# Remove specific words from the NLTK stopwords list
stop_words = set(stopwords.words('english'))
stop_words.update({'Hii', 'it', 'Product', 'Shuttle', 'hii', 'flipkart', 'flipkartread', 'product', 'productread', 'read', 'goodread','shuttle', 'Readmore'})


def preprocess(data):
    # Removes special characters
    sentence = re.sub("[^a-zA-Z]", " ", data)
    
    # Converts words to lowercase
    sentence = sentence.lower()
    
    # Tokenization
    sentence = sentence.split()
    
    # Removes the stop words
    sentence = [word for word in sentence if word not in stop_words]
    
    # Applying lemmatization
    sentence = [Lemmatization.lemmatize(word) for word in sentence]
    
    # Join the tokens back into a string
    sentence = " ".join(sentence)
    
    return sentence

# Apply preprocess function to the 'Review text' column in the Badminton dataset
Badminton['Cleaned Review Text'] = Badminton['Review text'].apply(preprocess)

# Display the modified dataset
# print(Badminton)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rjsek\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
Badminton
# Out:
#                Reviewer Name               Review Title  \
# 0               Kamal Suresh               Nice product
# 1          Flipkart Customer     Don't waste your money
# 2     A. S. Raja Srinivasan   Did not meet expectations
# 3                Baji Sankar      Mind-blowing purchase
# 4          Flipkart Customer                  Must buy!
# ...                      ...                        ...
# 8008     vishal kumar ashish                       Nice
# 8009         Nitya Nand  Rai                Good choice
# 8010             Tarun Reddy                    Awesome
# 8011             Jayachandra                  High cost
# 8012            vishnu varma                Really Nice
#
#                   Place of Review  Up Votes  Down Votes     Month  \
# 0      Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1      Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2     Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3      Certified Buyer, Hyderabad     173.0        45.0  Oct 2018
# 4     Certified Buyer, Doom Dooma     403.0       121.0  Jan 2020
# ...                           ...       ...         ...       ...
# 8008    Certified Buyer, Haridwar       0.0         0.0  Oct 2016
# 8009   Certified Buyer, Raebareli       0.0         0.0  Oct 2016
# 8010              Certified Buyer       0.0         0.0  Oct 2016
# 8011   Certified Buyer, Mangalore       0.0         0.0  Dec 2015
# 8012    Certified Buyer, Agartala       0.0         1.0  Sep 2016
#
#                                             Review text  Ratings Sentiment  \
# 0     Nice product, good quality, but price is now r...        4  Positive
# 1     They didn't supplied Yonex Mavis 350. Outside ...        1  Negative
# 2     Worst product. Damaged shuttlecocks packed in ...        1  Negative
# 3     Good quality product. Delivered on time.READ MORE        5  Positive
# 4     BEST PURCHASE It is a good quality and is more...        5  Positive
# ...                                                 ...      ...       ...
# 8008  Thanks to the delivery boy ... Service is alwa...        5  Positive
# 8009  Over priced even after 50% discount price is m...        1  Negative
# 8010  Too much priced. It was getting me for Rs. 640...        1  Negative
# 8011  Hii flipkart customers care..why your delivery...        5  Positive
# 8012                       Nice delivery speedREAD MORE        5  Positive
#
#                                     Cleaned Review Text
# 0     nice good quality price rising bad sign afford...
# 1     supplied yonex mavis outside cover yonex ad in...
# 2     worst damaged shuttlecock packed new box origi...
# 3                           good quality delivered time
# 4     best purchase good quality durable average shi...
# ...                                                 ...
# 8008         thanks delivery boy service always awesome
# 8009  priced even discount price much higher usual m...
# 8010  much priced getting r home town advantage purc...
# 8011  customer care delivery boy bring swipe machine...
# 8012                            nice delivery speedread
#
# [8013 rows x 10 columns]

# %%
# Creating wordcloud again to check most occured words

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all cleaned review text into a single string
text = ' '.join(Badminton['Cleaned Review Text'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the WordCloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Cleaned Review Text')
plt.axis('off')  # Turn off axis
plt.show()

# %%
# Finding top 10 words

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Assuming Badminton is your DataFrame containing the text data
# Assuming 'Cleaned Review Text' is the column containing cleaned text data

# Concatenate all cleaned text data into a single string
text_data = ' '.join(Badminton['Cleaned Review Text'])

# Tokenize the text into words
tokens = word_tokenize(text_data)

# Calculate word frequencies
word_freq = FreqDist(tokens)

# Get the n most common words
n = 10
top_words = word_freq.most_common(n)

# Print the top words
print("Top", n, "words:")
for word, freq in top_words:
    print(word, ":", freq)

# Plot word frequency distribution
word_freq.plot(n, cumulative=False)
plt.show()
# Out:
# Top 10 words:
# good : 2072
# quality : 789
# nice : 748
# niceread : 446
# qualityread : 419
# best : 397
# one : 327
# original : 322
# shuttle : 312
# delivery : 274

# %%
#

# %%
#applying preprocesing on train_data

x_train= x_train.apply(preprocess)

# %%
x_train
# Out:
# 3741                                          awesomeread
# 1125                                                 good
# 1232                    great highly recommended practice
# 5282                                    worst qualityread
# 7667                                 good value moneyread
#                               ...
# 7935                               good got best price fk
# 5192
# 3980                                            superread
# 235     love really guudas well fantastic delivery ear...
# 5157
# Name: Review text, Length: 6410, dtype: object

# %%
#

# %%
#applying preprocessing on test_data

x_test = x_test.apply(preprocess)

# %%
x_test
# Out:
# 2890                      bought totally bought priceread
# 1954                                         expectedread
# 6291
# 7900                                             niceread
# 5313                                         good nowread
#                               ...
# 7179                         timely delivery expectedread
# 1683
# 3104    good quality practice work min day playing int...
# 2174
# 899                                              niceread
# Name: Review text, Length: 1603, dtype: object

# %%
# Bag of Words / Count Vectorizer

# %%
# import feature extraction methods from sklearn
from sklearn.feature_extraction.text import CountVectorizer

# instantiate a vectorizer
vect = CountVectorizer(preprocessor=preprocess)

# use it to extract features from training data
# %time x_train_dtm = vect.fit_transform(x_train)

print(x_train_dtm.shape)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 84.6 ms
# (6410, 2602)

# %%
# TF - IDF

# %%
# Import TF-IDF vectorizer from sklearn
from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate a TF-IDF vectorizer
tfidf_vect = TfidfVectorizer(preprocessor=preprocess)

# Use it to extract features from training data
# %time x_train_tfidf = tfidf_vect.fit_transform(x_train)

print(x_train_tfidf.shape)

# %%
# BERT

# %%
! pip install transformers

# %%
from transformers import BertTokenizer, BertModel
import torch

# Load pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize input text
tokenized_texts = [tokenizer.tokenize(text) for text in x_train]

# Convert tokenized input to BERT input IDs
input_ids = [tokenizer.convert_tokens_to_ids(tokens) for tokens in tokenized_texts]

# Pad sequences to ensure uniform length
input_ids = torch.tensor([ids + [0] * (512 - len(ids)) for ids in input_ids])

# Load pre-trained BERT model
model = BertModel.from_pretrained('bert-base-uncased')

# Put the model in evaluation mode
model.eval()

# Extract BERT embeddings
with torch.no_grad():
    outputs = model(input_ids)

# Get BERT embeddings from the output
bert_embeddings = outputs[0]

print(bert_embeddings.shape)

# %%
#

# %%
# Step - Data Preprocessing on test data (X_test)

# transform testing data (using training data's features)
x_test_dtm = vect.transform(x_test)

print(x_test_dtm.shape)
# Out:
# (1603, 2602)

# %%
# Model Building

# %%
# Naive Bayes

# %%
# Train the model

# %%
# import classifiers from sklearn
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB() # instantiate a Multinomial Naive Bayes model
# %time nb.fit(x_train_dtm, y_train) # train the model(timing it with an IPython "magic command")
# Out:
# CPU times: total: 0 ns
# Wall time: 9.1 ms
# MultinomialNB()

# %%
# Evaluating on Train Data

# %%
from sklearn import metrics
# make class predictions for X_train_dtm
y_train_pred = nb.predict(x_train_dtm)

metrics.accuracy_score(y_train, y_train_pred)
# Out:
# 0.9400936037441497

# %%
#

# %%
metrics.confusion_matrix(y_train, y_train_pred)
# Out:
# array([[ 467,  315],
#        [  69, 5559]], dtype=int64)

# %%
#

# %%
cm = metrics.confusion_matrix(y_train, y_train_pred)
actual = np.sum(cm, axis=1).reshape(-1, 1)
cmn = np.round(cm/actual, 2)

sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=nb.classes_, yticklabels=nb.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 20.049999999999997, 'Predicted')

# %%
# Evaluation on Test Data

# %%
# make class predictions for X_test_dtm
y_test_pred = nb.predict(x_test_dtm)

metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.9151590767311292

# %%
cm = metrics.confusion_matrix(y_test, y_test_pred)
actual = np.sum(cm, axis=1).reshape(-1, 1)
cmn = np.round(cm/actual, 2)

sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=nb.classes_, yticklabels=nb.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 20.049999999999997, 'Predicted')

# %%
# Checking F1 Score

# %%
# # Understand that accuracy is influenced in the presence of data imbalance
# # Let's change the metric to F1 Score

# %%
print("Train Score (F1 Score):", metrics.f1_score(y_train, y_train_pred, average='weighted'))
print("Test Score (F1 Score):", metrics.f1_score(y_test, y_test_pred, average='weighted'))
# Out:
# Train Score (F1 Score): 0.9351435726909796
# Test Score (F1 Score): 0.9033154666522514

# %%
End
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 End
#
# NameError: name 'End' is not defined

# %%
# Caching and Memoization for faster results

# %%
from joblib import Memory
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from gensim.models import Word2Vec

# %%
# Define a memory object to cache intermediate results
cachedir = '.cache'
memory = Memory(location=cachedir, verbose=0)

pipelines = {
    'naive_bayes': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', MultinomialNB())
    ], memory=memory),
    'decision_tree': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', DecisionTreeClassifier())
    ], memory=memory),
    'logistic_regression': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', LogisticRegression())
    ], memory=memory)
}

# Define parameter grid for each algorithm
param_grids = {
    'naive_bayes': [
        {
            'vectorization': [CountVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000], 
            'classifier__alpha' : [1, 10]
        }
    ],
    'decision_tree': [
        {
        'vectorization': [CountVectorizer(),TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000],
            'classifier__max_depth': [None, 5, 10]
        }
    ],
    'logistic_regression': [
        {
            'vectorization': [CountVectorizer(), TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000], 
            'classifier__C': [0.1, 1, 10], 
            'classifier__penalty': ['elasticnet'], 
            'classifier__l1_ratio': [0.4, 0.5, 0.6],
            'classifier__solver': ['saga'],
            'classifier__class_weight': ['balanced']
        }
    ]
}

# Perform GridSearchCV for each algorithm
best_models = {}

for algo in pipelines.keys():
    print("*" * 10, algo, "*" * 10)
    grid_search = GridSearchCV(estimator=pipelines[algo], 
                               param_grid=param_grids[algo], 
                               cv=5, 
                               scoring='f1',  
                               return_train_score=True,
                               verbose=1)
    grid_search.fit(x_train, y_train)
    best_models[algo] = grid_search.best_estimator_
#     print('Score on Test Data:', grid_search.score(x_test, y_test, pos_label='Positive'))
    y_pred = grid_search.best_estimator_.predict(x_test)
    f1 = f1_score(y_test, y_pred, pos_label='Positive',average='weighted')  
    print('F1 Score on Test Data:', f1)

# %%
# 2

# %%
import os
import joblib
from joblib import Memory
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline

# Define a memory object to cache intermediate results
cachedir = '.cache'
memory = Memory(location=cachedir, verbose=0)

# Define pipelines for selected models
pipelines = {
    'naive_bayes': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', MultinomialNB())
    ], memory=memory),
    'decision_tree': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', DecisionTreeClassifier())
    ], memory=memory),
    'logistic_regression': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', LogisticRegression())
    ], memory=memory),
    'random_forest': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', RandomForestClassifier())
    ], memory=memory),
    'svm': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', SVC())
    ], memory=memory),
    'knn': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', KNeighborsClassifier())
    ], memory=memory)
}

# Define parameter grid for each algorithm
param_grids = {
    'naive_bayes': {
        'vectorization__max_features' : [1000, 2000, 5000],
        'classifier__alpha' : [1, 10]
    },
    'decision_tree': {
        'vectorization__max_features' : [1000, 2000, 5000],
        'classifier__max_depth': [None, 5, 10]
    },
    'logistic_regression': {
        'vectorization__max_features' : [1000, 2000, 5000],
        'classifier__C': [0.1, 1, 10],
        'classifier__penalty': ['l2']
    },
    'random_forest': {
        'vectorization__max_features' : [1000, 2000, 5000],
        'classifier__n_estimators': [50, 100, 200],
        'classifier__max_depth': [None, 5, 10]
    },
    'svm': {
        'vectorization__max_features' : [1000, 2000, 5000],
        'classifier__C': [0.1, 1, 10],
        'classifier__kernel': ['linear', 'rbf']
    },
    'knn': {
        'vectorization__max_features' : [1000, 2000, 5000],
        'classifier__n_neighbors': [3, 5, 10],
        'classifier__weights': ['uniform', 'distance']
    }
}

# Perform GridSearchCV for each algorithm
best_models = {}

for algo in pipelines.keys():
    print("*" * 10, algo, "*" * 10)
    grid_search = GridSearchCV(estimator=pipelines[algo],
                               param_grid=param_grids[algo],
                               cv=5,
                               scoring='f1',
                               return_train_score=True,
                               verbose=1)
    grid_search.fit(x_train, y_train)
    best_models[algo] = grid_search.best_estimator_
    y_pred = grid_search.best_estimator_.predict(x_test)
    f1 = f1_score(y_test, y_pred, pos_label='Positive', average='weighted')
    print('F1 Score on Test Data:', f1)

# %%
# 3 Optimised code

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import MinMaxScaler
import joblib
from joblib import Memory

# Define a memory object to cache intermediate results
cachedir = '.cache'
memory = Memory(location=cachedir, verbose=0)

# Define pipelines for selected models with both CountVectorizer and TfidfVectorizer
pipelines = {
    'naive_bayes': Pipeline([
        ('vectorization', FeatureUnion([
            ('count_vectorizer', CountVectorizer()),
            ('tfidf_vectorizer', TfidfVectorizer())
        ])),
        ('classifier', MultinomialNB())
    ], memory=memory),
    'decision_tree': Pipeline([
        ('vectorization', FeatureUnion([
            ('count_vectorizer', CountVectorizer()),
            ('tfidf_vectorizer', TfidfVectorizer())
        ])),
        ('classifier', DecisionTreeClassifier())
    ], memory=memory),
    'logistic_regression': Pipeline([
        ('vectorization', FeatureUnion([
            ('count_vectorizer', CountVectorizer()),
            ('tfidf_vectorizer', TfidfVectorizer())
        ])),
        ('classifier', LogisticRegression())
    ], memory=memory),
    'svm': Pipeline([
        ('vectorization', FeatureUnion([
            ('count_vectorizer', CountVectorizer()),
            ('tfidf_vectorizer', TfidfVectorizer())
        ])),
        ('classifier', SVC())
    ], memory=memory),
    'random_forest': Pipeline([
        ('vectorization', FeatureUnion([
            ('count_vectorizer', CountVectorizer()),
            ('tfidf_vectorizer', TfidfVectorizer())
        ])),
        ('classifier', RandomForestClassifier())
    ], memory=memory),
    'knn': Pipeline([
        ('vectorization', FeatureUnion([
            ('count_vectorizer', CountVectorizer()),
            ('tfidf_vectorizer', TfidfVectorizer())
        ])),
        ('classifier', KNeighborsClassifier())
    ], memory=memory)
}

# Define parameter grid for each algorithm
param_grids = {
    'naive_bayes': {
        'vectorization__count_vectorizer__max_features': [1000, 2000, 5000],
        'vectorization__tfidf_vectorizer__max_features': [1000, 2000, 5000],
        'classifier__alpha': [1, 10]
    },
    'decision_tree': {
        'vectorization__count_vectorizer__max_features': [1000, 2000, 5000],
        'vectorization__tfidf_vectorizer__max_features': [1000, 2000, 5000],
        'classifier__max_depth': [None, 5, 10]
    },
    'logistic_regression': {
        'vectorization__count_vectorizer__max_features': [1000, 2000, 5000],
        'vectorization__tfidf_vectorizer__max_features': [1000, 2000, 5000],
        'classifier__C': [0.1, 1, 10],
        'classifier__penalty': ['l2']
    },
    'svm': {
        'vectorization__count_vectorizer__max_features': [1000, 2000, 5000],
        'vectorization__tfidf_vectorizer__max_features': [1000, 2000, 5000],
        'classifier__C': [0.1, 1, 10],
        'classifier__kernel': ['linear', 'rbf']
    },
    'random_forest': {
        'vectorization__count_vectorizer__max_features': [1000, 2000, 5000],
        'vectorization__tfidf_vectorizer__max_features': [1000, 2000, 5000],
        'classifier__n_estimators': [50, 100, 200],
        'classifier__max_depth': [None, 5, 10]
    },
    'knn': {
        'vectorization__count_vectorizer__max_features': [1000, 2000, 5000],
        'vectorization__tfidf_vectorizer__max_features': [1000, 2000, 5000],
        'classifier__n_neighbors': [i for i in range(3, 21, 2)],  # Experiment with different values of n_neighbors
        'classifier__p': [1, 2, 3]
    }
}

# Perform GridSearchCV for each algorithm
best_models = {}

for algo in pipelines.keys():
    print("*" * 10, algo, "*" * 10)
    grid_search = GridSearchCV(estimator=pipelines[algo],
                               param_grid=param_grids[algo],
                               cv=5,
                               scoring='f1',
                               return_train_score=True,
                               verbose=1)
    grid_search.fit(x_train, y_train)
    best_models[algo] = grid_search.best_estimator_
    y_pred = grid_search.best_estimator_.predict(x_test)
    f1 = f1_score(y_test, y_pred, pos_label='Positive', average='weighted')
    print('F1 Score on Test Data:', f1)
# Out:
# ********** naive_bayes **********
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# F1 Score on Test Data: 0.9046105108293421
# ********** decision_tree **********
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# F1 Score on Test Data: 0.9007150981860287
# ********** logistic_regression **********
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# F1 Score on Test Data: 0.8938389972580804
# ********** svm **********
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# F1 Score on Test Data: 0.9031479355282601
# ********** random_forest **********
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# F1 Score on Test Data: 0.9040003251531277
# ********** knn **********
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# F1 Score on Test Data: 0.8723101979557961

# %%
# Getting best model

# %%
for name, model in best_models.items():
    print(f"{name}")
    print(f"{model}")
    print()
# Out:
# naive_bayes
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization',
#                  FeatureUnion(transformer_list=[('count_vectorizer',
#                                                  CountVectorizer(max_features=1000)),
#                                                 ('tfidf_vectorizer',
#                                                  TfidfVectorizer(max_features=1000))])),
#                 ('classifier', MultinomialNB(alpha=1))])
#
# decision_tree
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization',
#                  FeatureUnion(transformer_list=[('count_vectorizer',
#                                                  CountVectorizer(max_features=1000)),
#                                                 ('tfidf_vectorizer',
#                                                  TfidfVectorizer(max_features=1000))])),
#                 ('classifier', DecisionTreeClassifier())])
#
# logistic_regression
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization',
#                  FeatureUnion(transformer_list=[('count_vectorizer',
#                                                  CountVectorizer(max_features=1000)),
#                                                 ('tfidf_vectorizer',
#                                                  TfidfVectorizer(max_features=1000))])),
#                 ('classifier', LogisticRegression(C=0.1))])
#
# svm
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization',
#                  FeatureUnion(transformer_list=[('count_vectorizer',
#                                                  CountVectorizer(max_features=1000)),
#                                                 ('tfidf_vectorizer',
#                                                  TfidfVectorizer(max_features=1000))])),
#                 ('classifier', SVC(C=0.1, kernel='linear'))])
#
# random_forest
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization',
#                  FeatureUnion(transformer_list=[('count_vectorizer',
#                                                  CountVectorizer(max_features=1000)),
#                                                 ('tfidf_vectorizer',
#                                                  TfidfVectorizer(max_features=1000))])),
#                 ('classifier', RandomForestClassifier(n_estimators=50))])
#
# knn
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization',
#                  FeatureUnion(transformer_list=[('count_vectorizer',
#                                                  CountVectorizer(max_features=1000)),
#                                                 ('tfidf_vectorizer',
#                                                  TfidfVectorizer(max_features=1000))])),
#                 ('classifier', KNeighborsClassifier(n_neighbors=3, p=1))])

# %%
# Saving the model

# %%
save_dir = 'C:/Users/rjsek/OneDrive/Desktop/webapp/models'

for name, model in best_models.items():
    print("*" * 10, name, "*" * 10)
    
    joblib.dump(model, os.path.join(save_dir, f'{name}.pkl'))
    loaded_model = joblib.load(os.path.join(save_dir, f'{name}.pkl'))
    
    # %time y_test_pred = loaded_model.predict(x_test)

    f1 = f1_score(y_test, y_test_pred, pos_label='Positive', average='weighted')

    print("F1 Score (Positive Class):", f1)
    print("Model Size:", os.path.getsize(os.path.join(save_dir, f'{name}.pkl')), "Bytes")
# Out:
# ********** naive_bayes **********
# CPU times: total: 31.2 ms
# Wall time: 11 ms
# F1 Score (Positive Class): 0.9046105108293421
# Model Size: 178423 Bytes
# ********** decision_tree **********
# CPU times: total: 0 ns
# Wall time: 12 ms
# F1 Score (Positive Class): 0.9007150981860287
# Model Size: 193033 Bytes
# ********** logistic_regression **********
# CPU times: total: 0 ns
# Wall time: 11 ms
# F1 Score (Positive Class): 0.8938389972580804
# Model Size: 130594 Bytes
# ********** svm **********
# CPU times: total: 62.5 ms
# Wall time: 62.7 ms
# F1 Score (Positive Class): 0.9031479355282601
# Model Size: 285525 Bytes
# ********** random_forest **********
# CPU times: total: 62.5 ms
# Wall time: 39.1 ms
# F1 Score (Positive Class): 0.9040003251531277
# Model Size: 5772927 Bytes
# ********** knn **********
# CPU times: total: 1.55 s
# Wall time: 130 ms
# F1 Score (Positive Class): 0.8723101979557961
# Model Size: 560930 Bytes
